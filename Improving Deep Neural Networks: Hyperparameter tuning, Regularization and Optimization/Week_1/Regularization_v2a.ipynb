# %% [markdown]
# # Regularization
#
# Welcome to the second assignment of this week. Deep Learning models have so much flexibility and capacity that **overfitting can be a serious problem**, if the training dataset is not big enough. Sure it does well on the training set, but the learned network **doesn't generalize to new examples** that it has never seen!
#
# **You will learn to:** Use regularization in your deep learning models.
#
# Let's first import the packages you are going to use.

# %% [markdown]
# ### <font color='darkblue'> Updates to Assignment <font>
#
# #### If you were working on a previous version
# * The current notebook filename is version "2a".
# * You can find your work in the file directory as version "2".
# * To see the file directory, click on the Coursera logo at the top left of the notebook.
#
# #### List of Updates
# * Clarified explanation of 'keep_prob' in the text description.
# * Fixed a comment so that keep_prob and 1-keep_prob add up to 100%
# * Updated print statements and 'expected output' for easier visual comparisons.

# %%
# import packages
import numpy as np
import matplotlib.pyplot as plt
from reg_utils import sigmoid, relu, plot_decision_boundary, initialize_parameters, load_2D_dataset, predict_dec
from reg_utils import compute_cost, predict, forward_propagation, backward_propagation, update_parameters
import sklearn
import sklearn.datasets
import scipy.io
from testCases import *

# %matplotlib inline
plt.rcParams['figure.figsize'] = (7.0, 4.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %% [markdown]
# **Problem Statement**: You have just been hired as an AI expert by the French Football Corporation. They would like you to recommend positions where France's goal keeper should kick the ball so that the French team's players can then hit it with their head.
#
# <img src="images/field_kiank.png" style="width:600px;height:350px;">
# <caption><center> <u> **Figure 1** </u>: **Football field**<br> The goal keeper kicks the ball in the air, the players of each team are fighting to hit the ball with their head </center></caption>
#
#
# They give you the following 2D dataset from France's past 10 games.

# %%
train_X, train_Y, test_X, test_Y = load_2D_dataset()

# %% [markdown]
# Each dot corresponds to a position on the football field where a football player has hit the ball with his/her head after the French goal keeper has shot the ball from the left side of the football field.
# - If the dot is blue, it means the French player managed to hit the ball with his/her head
# - If the dot is red, it means the other team's player hit the ball with their head
#
# **Your goal**: Use a deep learning model to find the positions on the field where the goalkeeper should kick the ball.

# %% [markdown]
# **Analysis of the dataset**: This dataset is a little noisy, but it looks like a diagonal line separating the upper left half (blue) from the lower right half (red) would work well.
#
# You will first try a non-regularized model. Then you'll learn how to regularize it and decide which model you will choose to solve the French Football Corporation's problem.

# %% [markdown]
# ## 1 - Non-regularized model
#
# You will use the following neural network (already implemented for you below). This model can be used:
# - in *regularization mode* -- by setting the `lambd` input to a non-zero value. We use "`lambd`" instead of "`lambda`" because "`lambda`" is a reserved keyword in Python.
# - in *dropout mode* -- by setting the `keep_prob` to a value less than one
#
# You will first try the model without any regularization. Then, you will implement:
# - *L2 regularization* -- functions: "`compute_cost_with_regularization()`" and "`backward_propagation_with_regularization()`"
# - *Dropout* -- functions: "`forward_propagation_with_dropout()`" and "`backward_propagation_with_dropout()`"
#
# In each part, you will run this model with the correct inputs so that it calls the functions you've implemented. Take a look at the code below to familiarize yourself with the model.

# %%
def model(X,Y,learning_rate=0.3,num_iterations=30000,print_cost=True,lambd=0,keep_prob=1):
    grads={}
    costs=[]
    m=X.shape[1]
    layers_dims=[X.shape[0],20,3,1]
    parameters=initialize_parameters(layers_dims)
    for i in range(0,num_iterations):
        if keep_prob==1:
            a3,cache=forward_propagation(X,parameters)
        elif keep_prob<1:
            a3,cache=forward_propagation_with_dropout(X,parameters,keep_prob)
        
        if lambd==0:
            cost=compute_cost(a3,Y)
        else:
            cost=compute_cost_with_regularization(a3,Y,parameters,lambd)
        assert(lambd==0 or keep_prob==1)
        
        if lambd==0 and keep_prob==1:
            grads=backward_propagation(X,Y,cache)
        elif lambd!=0:
            grads=backward_propagation_with_regularization(X,Y,cache,lambd)
        elif keep_prob<1:
            grads=backward_propagation_with_dropout(X,Y,cache,keep_prob)
        parameters=update_parameters(parameters,grads,learning_rate)
        if print_cost and i&10000==0:
            print("Cost after iteration {}:{}".format(i,cost))
        if print_cost and i%1000==0:
            costs.append(cost)
    
    plt.plot(costs)
    plt.ylabel('cost')
    plt.xlabel('iterations (x1,000)')
    plt.title("learning rate ="+str(learning_rate))
    plt.show()
    return parameters

# %% [markdown]
# Let's train the model without any regularization, and observe the accuracy on the train/test sets.

# %%
parameters = model(train_X, train_Y)
print ("On the training set:")
predictions_train = predict(train_X, train_Y, parameters)
print ("On the test set:")
predictions_test = predict(test_X, test_Y, parameters)
# Out:
# Cost after iteration 0:0.6557412523481002
# Cost after iteration 1:0.6489123432561924
# Cost after iteration 2:0.642014877944059
# Cost after iteration 3:0.6347362221153536
# Cost after iteration 4:0.6269403015534099
# Cost after iteration 5:0.6186224310735186
# Cost after iteration 6:0.6097586173851115
# Cost after iteration 7:0.6006538675566222
# Cost after iteration 8:0.5913975617212393
# Cost after iteration 9:0.5817931183235693
# Cost after iteration 10:0.5720711392341776
# Cost after iteration 11:0.5622819730422609
# Cost after iteration 12:0.5525174666341147
# Cost after iteration 13:0.5427297768721415
# Cost after iteration 14:0.5327586535500185
# Cost after iteration 15:0.5222458215525146
# Cost after iteration 32:0.3660898233819221
# Cost after iteration 33:0.35901166965773934
# Cost after iteration 34:0.3522506824544308
# Cost after iteration 35:0.34579482768584985
# Cost after iteration 36:0.3395927344809263
# Cost after iteration 37:0.33365065627635665
# Cost after iteration 38:0.328001487576949
# Cost after iteration 39:0.3226948894730522
# Cost after iteration 40:0.31769527449252577
# Cost after iteration 41:0.31299235452937113
# Cost after iteration 42:0.30858381824154624
# Cost after iteration 43:0.3044255296506165
# Cost after iteration 44:0.3005119041616242
# Cost after iteration 45:0.29683266741418823
# Cost after iteration 46:0.29338999259870285
# Cost after iteration 47:0.2901605473310096
# Cost after iteration 64:0.2566528767317226
# Cost after iteration 65:0.25553828637519327
# Cost after iteration 66:0.2544868503008531
# Cost after iteration 67:0.2534875405596917
# Cost after iteration 68:0.252540798504229
# Cost after iteration 69:0.25165070564719766
# Cost after iteration 70:0.2508172504764858
# Cost after iteration 71:0.25003127613761295
# Cost after iteration 72:0.24928776625647983
# Cost after iteration 73:0.24858077874173148
# Cost after iteration 74:0.24790930369117492
# Cost after iteration 75:0.2472726236813546
# Cost after iteration 76:0.24666837715264747
# Cost after iteration 77:0.2460951586011463
# Cost after iteration 78:0.2455515846278016
# Cost after iteration 79:0.24503217459408558
# Cost after iteration 22730:0.1321485663515427
# Cost after iteration 22731:0.1335599060399935
# Cost after iteration 22732:0.13315245567684328
# Cost after iteration 22733:0.13592478344567496
# Cost after iteration 22734:0.13528468002998306
# Cost after iteration 22735:0.1360171531170476
# Cost after iteration 22752:0.12959204696853174
# Cost after iteration 22753:0.13029389075034672
# Cost after iteration 22754:0.13076021234587196
# Cost after iteration 22755:0.13420118081614796
# Cost after iteration 22756:0.13258494057512327
# Cost after iteration 22757:0.13415437708951966
# Cost after iteration 22758:0.13573751828922578
# Cost after iteration 22759:0.13978909794156666
# Cost after iteration 22760:0.13868031626671343
# Cost after iteration 22761:0.13908566798362326
# Cost after iteration 22762:0.14015142134590478
# Cost after iteration 22763:0.14261488684560414
# Cost after iteration 22764:0.14005513212653947
# Cost after iteration 22765:0.13979414055476233
# Cost after iteration 22766:0.14028237096305485
# Cost after iteration 22767:0.13927884573912847
# On the training set:
# Accuracy: 0.947867298578
# On the test set:
# Accuracy: 0.915

# %% [markdown]
# The train accuracy is 94.8% while the test accuracy is 91.5%. This is the **baseline model** (you will observe the impact of regularization on this model). Run the following code to plot the decision boundary of your model.

# %%
plt.title("Model without regularization")
axes = plt.gca()
axes.set_xlim([-0.75,0.40])
axes.set_ylim([-0.75,0.65])
plot_decision_boundary(lambda x: predict_dec(parameters, x.T), train_X, train_Y)

# %% [markdown]
# The non-regularized model is obviously overfitting the training set. It is fitting the noisy points! Lets now look at two techniques to reduce overfitting.

# %% [markdown]
# ## 2 - L2 Regularization
#
# The standard way to avoid overfitting is called **L2 regularization**. It consists of appropriately modifying your cost function, from:
# $$J = -\frac{1}{m} \sum\limits_{i = 1}^{m} \large{(}\small  y^{(i)}\log\left(a^{[L](i)}\right) + (1-y^{(i)})\log\left(1- a^{[L](i)}\right) \large{)} \tag{1}$$
# To:
# $$J_{regularized} = \small \underbrace{-\frac{1}{m} \sum\limits_{i = 1}^{m} \large{(}\small y^{(i)}\log\left(a^{[L](i)}\right) + (1-y^{(i)})\log\left(1- a^{[L](i)}\right) \large{)} }_\text{cross-entropy cost} + \underbrace{\frac{1}{m} \frac{\lambda}{2} \sum\limits_l\sum\limits_k\sum\limits_j W_{k,j}^{[l]2} }_\text{L2 regularization cost} \tag{2}$$
#
# Let's modify your cost and observe the consequences.
#
# **Exercise**: Implement `compute_cost_with_regularization()` which computes the cost given by formula (2). To calculate $\sum\limits_k\sum\limits_j W_{k,j}^{[l]2}$  , use :
# ```python
# np.sum(np.square(Wl))
# ```
# Note that you have to do this for $W^{[1]}$, $W^{[2]}$ and $W^{[3]}$, then sum the three terms and multiply by $ \frac{1}{m} \frac{\lambda}{2} $.

# %%
# GRADED FUNCTION: compute_cost_with_regularization

def compute_cost_with_regularization(A3, Y, parameters, lambd):
    """
    Implement the cost function with L2 regularization. See formula (2) above.
    
    Arguments:
    A3 -- post-activation, output of forward propagation, of shape (output size, number of examples)
    Y -- "true" labels vector, of shape (output size, number of examples)
    parameters -- python dictionary containing parameters of the model
    
    Returns:
    cost - value of the regularized loss function (formula (2))
    """
    m = Y.shape[1]
    W1 = parameters["W1"]
    W2 = parameters["W2"]
    W3 = parameters["W3"]
    
    cross_entropy_cost = compute_cost(A3, Y) # This gives you the cross-entropy part of the cost
    
    ### START CODE HERE ### (approx. 1 line)
    L2_regularization_cost = lambd*0.5*(1/m)*(np.sum(np.square(W1))+np.sum(np.square(W2))+np.sum(np.square(W3)))
    ### END CODER HERE ###
    
    cost = cross_entropy_cost + L2_regularization_cost
    
    return cost

# %%
A3, Y_assess, parameters = compute_cost_with_regularization_test_case()

print("cost = " + str(compute_cost_with_regularization(A3, Y_assess, parameters, lambd = 0.1)))
# Out:
# cost = 1.78648594516

# %% [markdown]
# **Expected Output**:
#
# <table>
#     <tr>
#     <td>
#     **cost**
#     </td>
#         <td>
#     1.78648594516
#     </td>
#
#     </tr>
#
# </table>

# %% [markdown]
# Of course, because you changed the cost, you have to change backward propagation as well! All the gradients have to be computed with respect to this new cost.
#
# **Exercise**: Implement the changes needed in backward propagation to take into account regularization. The changes only concern dW1, dW2 and dW3. For each, you have to add the regularization term's gradient ($\frac{d}{dW} ( \frac{1}{2}\frac{\lambda}{m}  W^2) = \frac{\lambda}{m} W$).

# %%
# GRADED FUNCTION: backward_propagation_with_regularization

def backward_propagation_with_regularization(X, Y, cache, lambd):
    """
    Implements the backward propagation of our baseline model to which we added an L2 regularization.
    
    Arguments:
    X -- input dataset, of shape (input size, number of examples)
    Y -- "true" labels vector, of shape (output size, number of examples)
    cache -- cache output from forward_propagation()
    lambd -- regularization hyperparameter, scalar
    
    Returns:
    gradients -- A dictionary with the gradients with respect to each parameter, activation and pre-activation variables
    """
    
    m = X.shape[1]
    (Z1, A1, W1, b1, Z2, A2, W2, b2, Z3, A3, W3, b3) = cache
    
    dZ3 = A3 - Y
    
    ### START CODE HERE ### (approx. 1 line)
    dW3 = 1./m * np.dot(dZ3, A2.T) + (lambd*W3/m)
    ### END CODE HERE ###
    db3 = 1./m * np.sum(dZ3, axis=1, keepdims = True)
    
    dA2 = np.dot(W3.T, dZ3)
    dZ2 = np.multiply(dA2, np.int64(A2 > 0))
    ### START CODE HERE ### (approx. 1 line)
    dW2 = 1./m * np.dot(dZ2, A1.T) + (lambd*W2/m)
    ### END CODE HERE ###
    db2 = 1./m * np.sum(dZ2, axis=1, keepdims = True)
    
    dA1 = np.dot(W2.T, dZ2)
    dZ1 = np.multiply(dA1, np.int64(A1 > 0))
    ### START CODE HERE ### (approx. 1 line)
    dW1 = 1./m * np.dot(dZ1, X.T) + (lambd*W1/m)
    ### END CODE HERE ###
    db1 = 1./m * np.sum(dZ1, axis=1, keepdims = True)
    
    gradients = {"dZ3": dZ3, "dW3": dW3, "db3": db3,"dA2": dA2,
                 "dZ2": dZ2, "dW2": dW2, "db2": db2, "dA1": dA1, 
                 "dZ1": dZ1, "dW1": dW1, "db1": db1}
    
    return gradients

# %%
X_assess, Y_assess, cache = backward_propagation_with_regularization_test_case()

grads = backward_propagation_with_regularization(X_assess, Y_assess, cache, lambd = 0.7)
print ("dW1 = \n"+ str(grads["dW1"]))
print ("dW2 = \n"+ str(grads["dW2"]))
print ("dW3 = \n"+ str(grads["dW3"]))
# Out:
# dW1 =
# [[-0.25604646  0.12298827 -0.28297129]
#  [-0.17706303  0.34536094 -0.4410571 ]]
# dW2 =
# [[ 0.79276486  0.85133918]
#  [-0.0957219  -0.01720463]
#  [-0.13100772 -0.03750433]]
# dW3 =
# [[-1.77691347 -0.11832879 -0.09397446]]

# %% [markdown]
# **Expected Output**:
#
# ```
# dW1 =
# [[-0.25604646  0.12298827 -0.28297129]
#  [-0.17706303  0.34536094 -0.4410571 ]]
# dW2 =
# [[ 0.79276486  0.85133918]
#  [-0.0957219  -0.01720463]
#  [-0.13100772 -0.03750433]]
# dW3 =
# [[-1.77691347 -0.11832879 -0.09397446]]
# ```

# %% [markdown]
# Let's now run the model with L2 regularization $(\lambda = 0.7)$. The `model()` function will call:
# - `compute_cost_with_regularization` instead of `compute_cost`
# - `backward_propagation_with_regularization` instead of `backward_propagation`

# %%
parameters = model(train_X, train_Y, lambd = 0.7)
print ("On the train set:")
predictions_train = predict(train_X, train_Y, parameters)
print ("On the test set:")
predictions_test = predict(test_X, test_Y, parameters)
# Out:
# Cost after iteration 0:0.6974484493131264
# Cost after iteration 1:0.690748310065176
# Cost after iteration 2:0.6840235664480332
# Cost after iteration 3:0.676960901233318
# Cost after iteration 4:0.6694264265464979
# Cost after iteration 5:0.6614424555526874
# Cost after iteration 6:0.652931793240214
# Cost after iteration 7:0.6442579372814305
# Cost after iteration 8:0.6354107884686712
# Cost after iteration 9:0.626234031425738
# Cost after iteration 10:0.6169687814459781
# Cost after iteration 11:0.6076920911430178
# Cost after iteration 12:0.5985407859314987
# Cost after iteration 13:0.5893020624764357
# Cost after iteration 14:0.5798878882143398
# Cost after iteration 15:0.5699483252101311
# Cost after iteration 32:0.4233361598546547
# Cost after iteration 33:0.4166361033525248
# Cost after iteration 34:0.4101951064909941
# Cost after iteration 35:0.4039836998187514
# Cost after iteration 36:0.3980401183026217
# Cost after iteration 37:0.3923760034683363
# Cost after iteration 38:0.38704367857594096
# Cost after iteration 39:0.3819817043430964
# Cost after iteration 40:0.37723920569104874
# Cost after iteration 41:0.3727565922180714
# Cost after iteration 42:0.36852215763541263
# Cost after iteration 43:0.36452943831281276
# Cost after iteration 44:0.36079805339980936
# Cost after iteration 45:0.3572834273411305
# Cost after iteration 46:0.3539757527986771
# Cost after iteration 47:0.3508371273809754
# Cost after iteration 64:0.31858862327672455
# Cost after iteration 65:0.31756030908033905
# Cost after iteration 66:0.3165932645402986
# Cost after iteration 67:0.31567800548365915
# Cost after iteration 68:0.3148143106637863
# Cost after iteration 69:0.3139906159892869
# Cost after iteration 70:0.3132063154815451
# Cost after iteration 71:0.3124643116705834
# Cost after iteration 72:0.3117626944117534
# Cost after iteration 73:0.3110925656982993
# Cost after iteration 74:0.3104508837919195
# Cost after iteration 75:0.30983957186565225
# Cost after iteration 76:0.3092575510697964
# Cost after iteration 77:0.30870488142868596
# Cost after iteration 78:0.3081797624447226
# Cost after iteration 79:0.30767948931638084
# Cost after iteration 96:0.30163169119249794
# Cost after iteration 97:0.30136991738520125
# Cost after iteration 98:0.3011206571601193
# Cost after iteration 99:0.3008823469619655
# Cost after iteration 100:0.30065029640773444
# Cost after iteration 101:0.3004267563704812
# Cost after iteration 102:0.3002130009375385
# Cost after iteration 103:0.30000894688776364
# Cost after iteration 104:0.2998109218400612
# Cost after iteration 105:0.2996185177709289
# Cost after iteration 106:0.29942076243510807
# Cost after iteration 107:0.2992277772485013
# Cost after iteration 108:0.2990408878322648
# Cost after iteration 109:0.29885864691314995
# Cost after iteration 110:0.2986816077268778
# Cost after iteration 111:0.2985016121038595
# Cost after iteration 128:0.2956337290925022
# Cost after iteration 129:0.29549566222986473
# Cost after iteration 130:0.29537027525010096
# Cost after iteration 131:0.29524797073557846
# Cost after iteration 132:0.2951276523572014
# Cost after iteration 133:0.2950096225309137
# Cost after iteration 134:0.2948939160009821
# Cost after iteration 135:0.29478052751459144
# Cost after iteration 136:0.29467140248220713
# Cost after iteration 137:0.29456356095575353
# Cost after iteration 138:0.29445744645075456
# Cost after iteration 139:0.2943532443678278
# Cost after iteration 140:0.294250508319201
# Cost after iteration 141:0.29414959316823847
# Cost after iteration 142:0.2940507013899981
# Cost after iteration 143:0.2939523643688999
# Cost after iteration 160:0.29235823137287464
# Cost after iteration 161:0.29226983226877595
# Cost after iteration 162:0.2921829532586361
# Cost after iteration 163:0.2920957266164394
# Cost after iteration 164:0.2920090835787377
# Cost after iteration 165:0.2919270875688431
# Cost after iteration 166:0.2918504646141589
# Cost after iteration 167:0.29177505548579286
# Cost after iteration 168:0.29170080225957146
# Cost after iteration 169:0.29162717515765846
# Cost after iteration 170:0.2915535647607685
# Cost after iteration 171:0.2914809025600975
# Cost after iteration 172:0.29140915967070036
# Cost after iteration 173:0.29133713914530524
# Cost after iteration 174:0.29126558447168205
# Cost after iteration 175:0.2911950964039399
# Cost after iteration 192:0.29012933286508535
# Cost after iteration 193:0.290072734519518
# Cost after iteration 194:0.2900172592510972
# Cost after iteration 195:0.2899617369693456
# Cost after iteration 196:0.28990596567857213
# Cost after iteration 197:0.28985120602894443
# Cost after iteration 198:0.28979611817308243
# Cost after iteration 199:0.28974080046728495
# Cost after iteration 200:0.2896872798031903
# Cost after iteration 201:0.2896327622764746
# Cost after iteration 202:0.2895787366624505
# Cost after iteration 203:0.2895254590788382
# Cost after iteration 204:0.2894713345770464
# Cost after iteration 205:0.28941828810332904
# Cost after iteration 206:0.28936499158294865
# Cost after iteration 207:0.28931161948381
# Cost after iteration 224:0.28843860325378756
# Cost after iteration 225:0.28838949045773643
# Cost after iteration 226:0.288338959714116
# Cost after iteration 227:0.28829018460764927
# Cost after iteration 228:0.2882403546732436
# Cost after iteration 229:0.2881910642923575
# Cost after iteration 230:0.28814332961633937
# Cost after iteration 231:0.2880967909813358
# Cost after iteration 232:0.28805094270007187
# Cost after iteration 233:0.2880046881078634
# Cost after iteration 234:0.2879602126127551
# Cost after iteration 235:0.28791431592770267
# Cost after iteration 236:0.2878696924482655
# Cost after iteration 237:0.28782431417743315
# Cost after iteration 238:0.2877797050418637
# Cost after iteration 239:0.2877349191807616
# Cost after iteration 2048:0.2702144154625016
# Cost after iteration 2049:0.2702457059386355
# Cost after iteration 2050:0.27023492831518997
# Cost after iteration 2051:0.2702534657858057
# Cost after iteration 2052:0.2702350669573178
# Cost after iteration 2053:0.27024417983233073
# Cost after iteration 2054:0.2702350373057753
# Cost after iteration 2055:0.2702640626749453
# Cost after iteration 2056:0.2702526199043303
# Cost after iteration 2057:0.27027991170190785
# Cost after iteration 2058:0.2702591686091405
# Cost after iteration 2059:0.27026471534815594
# Cost after iteration 2060:0.2702509125128727
# Cost after iteration 2061:0.2702710849121231
# Cost after iteration 2062:0.2702529282194692
# Cost after iteration 2063:0.27029601235702605
# Cost after iteration 2080:0.270283316398095
# Cost after iteration 2081:0.2702937133123726
# Cost after iteration 2082:0.27026954758127325
# Cost after iteration 2083:0.27028400254994583
# Cost after iteration 2084:0.27026013488772443
# Cost after iteration 2085:0.27029873055785525
# Cost after iteration 2086:0.2702777293357051
# Cost after iteration 2087:0.270288519850307
# Cost after iteration 2088:0.27026729974573027
# Cost after iteration 2089:0.2702778277396368
# Cost after iteration 2090:0.2702557852337113
# Cost after iteration 2091:0.2702696370734865
# Cost after iteration 2092:0.27024765606238554
# Cost after iteration 2093:0.27025568996648763
# Cost after iteration 2094:0.2702357181182816
# Cost after iteration 2095:0.27027880074246186
# Cost after iteration 2112:0.2702037460051462
# Cost after iteration 2113:0.27020608785737255
# Cost after iteration 2114:0.27018527694465766
# Cost after iteration 2115:0.27021865142125234
# Cost after iteration 2116:0.2701943019032588
# Cost after iteration 2117:0.2701910629214756
# Cost after iteration 2118:0.2701756875241422
# Cost after iteration 2119:0.27018279057275196
# Cost after iteration 2120:0.27016666078169
# Cost after iteration 2121:0.27019762020589966
# Cost after iteration 2122:0.27017495940049524
# Cost after iteration 2123:0.2701715979573293
# Cost after iteration 2124:0.27015517614900963
# Cost after iteration 2125:0.2701642912508629
# Cost after iteration 2126:0.27014350573845736
# Cost after iteration 2127:0.2701792611931527
# Cost after iteration 2144:0.2700830976420129
# Cost after iteration 2145:0.27010800595215884
# Cost after iteration 2146:0.27008710172557143
# Cost after iteration 2147:0.27008423492285166
# Cost after iteration 2148:0.2700684513682832
# Cost after iteration 2149:0.27006671378073677
# Cost after iteration 2150:0.27005308979483783
# Cost after iteration 2151:0.27006334510613084
# Cost after iteration 2152:0.2700450509039312
# Cost after iteration 2153:0.27006863623636823
# Cost after iteration 2154:0.27005626235571817
# Cost after iteration 2155:0.2700597958433109
# Cost after iteration 2156:0.2700411354144098
# Cost after iteration 2157:0.27003602740569693
# Cost after iteration 2158:0.27002433315119045
# Cost after iteration 2159:0.2700321762367052
# Cost after iteration 2176:0.26998665861926546
# Cost after iteration 2177:0.270025574704808
# Cost after iteration 2178:0.2700102773852799
# Cost after iteration 2179:0.26999667390420123
# Cost after iteration 20494:0.2680197778669383
# Cost after iteration 20495:0.2679924600171206
# Cost after iteration 20512:0.26809195736936864
# Cost after iteration 20513:0.2680749268592577
# Cost after iteration 20514:0.26806305337577757
# Cost after iteration 20515:0.26812262852711727
# Cost after iteration 20516:0.2681025803825649
# Cost after iteration 20517:0.2680672941858789
# Cost after iteration 20518:0.2680515146160456
# Cost after iteration 20519:0.26803994477958043
# Cost after iteration 20520:0.26803963876320824
# Cost after iteration 20521:0.2680583833570081
# Cost after iteration 20522:0.2680527545646342
# Cost after iteration 20523:0.26805968406374153
# Cost after iteration 20524:0.2680546654671806
# Cost after iteration 20525:0.26805100796196096
# Cost after iteration 20526:0.2680442663080103
# Cost after iteration 20527:0.26804041000954343
# Cost after iteration 20544:0.2680290316055302
# Cost after iteration 20545:0.26808567745682277
# Cost after iteration 20546:0.26807469667000344
# Cost after iteration 20547:0.26803917751974954
# Cost after iteration 20548:0.26804505871042184
# Cost after iteration 20549:0.2680770397944292
# Cost after iteration 20550:0.2681204959228915
# Cost after iteration 20551:0.2681042683772641
# Cost after iteration 20552:0.26808985821782927
# Cost after iteration 20553:0.2681395571908954
# Cost after iteration 20554:0.2681212855648873
# Cost after iteration 20555:0.2680895320628549
# Cost after iteration 20556:0.268069107323583
# Cost after iteration 20557:0.268112407423792
# Cost after iteration 20558:0.2680964105662135
# Cost after iteration 20559:0.26806008475525006
# Cost after iteration 20576:0.26803358668196525
# Cost after iteration 20577:0.268003600669154
# Cost after iteration 20578:0.2680039361796264
# Cost after iteration 20579:0.2680500775204848
# Cost after iteration 20580:0.2680467795914938
# Cost after iteration 20581:0.26803706282139894
# Cost after iteration 20582:0.26803509390979363
# Cost after iteration 20583:0.2680600894391267
# Cost after iteration 20584:0.26805113719980644
# Cost after iteration 20585:0.2680152794370825
# Cost after iteration 20586:0.2679618383636281
# Cost after iteration 20587:0.26802227068730616
# Cost after iteration 20588:0.2680116320664819
# Cost after iteration 20589:0.26798651406284074
# Cost after iteration 20590:0.267983939782673
# Cost after iteration 20591:0.2680219004292228
# Cost after iteration 20608:0.2680289030964401
# Cost after iteration 20609:0.2680774092207005
# Cost after iteration 20610:0.26806833135615227
# Cost after iteration 20611:0.26806486467506385
# Cost after iteration 20612:0.2680479507441965
# Cost after iteration 20613:0.2680595662806752
# Cost after iteration 20614:0.26805307923040456
# Cost after iteration 20615:0.26803305602901684
# Cost after iteration 20616:0.2680346660674227
# Cost after iteration 20617:0.2680253160574273
# Cost after iteration 20618:0.2679688298440485
# Cost after iteration 20619:0.26799758934314183
# Cost after iteration 20620:0.26800024624303376
# Cost after iteration 20621:0.268003306503744
# Cost after iteration 20622:0.26799893165939204
# Cost after iteration 20623:0.26803577625838104
# Cost after iteration 20640:0.2680462461435156
# Cost after iteration 20641:0.2680847882824565
# Cost after iteration 20642:0.2680763094890803
# Cost after iteration 20643:0.2680386391883586
# Cost after iteration 20644:0.26803041526675286
# Cost after iteration 20645:0.26807040518444103
# Cost after iteration 20646:0.26806394880706635
# Cost after iteration 20647:0.2680470402420808
# Cost after iteration 20648:0.26803636783069706
# Cost after iteration 20649:0.268068620510494
# Cost after iteration 20650:0.26800311392486476
# Cost after iteration 20651:0.2679842371442064
# Cost after iteration 20652:0.26797248205834234
# Cost after iteration 20653:0.26802619485402157
# Cost after iteration 20654:0.26801680033259867
# Cost after iteration 20655:0.26799051057313455
# Cost after iteration 20672:0.2680047879855072
# Cost after iteration 20673:0.2679796386111185
# Cost after iteration 20674:0.2680451020885557
# Cost after iteration 20675:0.26810893543994974
# Cost after iteration 20676:0.26808863407878064
# Cost after iteration 20677:0.26806626895662644
# Cost after iteration 20678:0.2680479839739885
# Cost after iteration 20679:0.26807115881697996
# Cost after iteration 20680:0.268057281173338
# Cost after iteration 20681:0.26806587807037424
# Cost after iteration 20682:0.26804670947982945
# Cost after iteration 20683:0.2680658137085591
# Cost after iteration 20684:0.2680569483380205
# Cost after iteration 20685:0.2680506091689396
# Cost after iteration 20686:0.2680384071322143
# Cost after iteration 20687:0.2680772050151816
# Cost after iteration 20704:0.26798075241151825
# Cost after iteration 20705:0.268031251503621
# Cost after iteration 20706:0.268024716740796
# Cost after iteration 20707:0.26800005296894763
# Cost after iteration 20708:0.2679930106050457
# Cost after iteration 20709:0.2680359402827126
# Cost after iteration 20710:0.2680493792814065
# Cost after iteration 20711:0.2680388991913121
# Cost after iteration 20712:0.26807727249254426
# Cost after iteration 20713:0.2681116892554299
# Cost after iteration 20714:0.26809521326909874
# Cost after iteration 20715:0.2680716734292658
# Cost after iteration 20716:0.26805294354815185
# Cost after iteration 20717:0.26806543737476807
# Cost after iteration 20718:0.26805519770721625
# Cost after iteration 20719:0.26807115390182557
# Cost after iteration 22528:0.26805816537090355
# Cost after iteration 22529:0.26803858431490546
# Cost after iteration 22530:0.26804646390110043
# Cost after iteration 22531:0.26806946179797864
# Cost after iteration 22532:0.268068737690284
# Cost after iteration 22533:0.26807429888496903
# Cost after iteration 22534:0.26807519513743777
# Cost after iteration 22535:0.26807622691899824
# Cost after iteration 22536:0.26804947521169653
# Cost after iteration 22537:0.2680441523635376
# Cost after iteration 22538:0.26803447843560857
# Cost after iteration 22539:0.2680670711310807
# Cost after iteration 22540:0.2680442090541872
# Cost after iteration 22541:0.2680246258645905
# Cost after iteration 22542:0.26801427174334463
# Cost after iteration 22543:0.26802429437494474
# Cost after iteration 22560:0.26806036480835593
# Cost after iteration 22561:0.26803717192374993
# Cost after iteration 22562:0.2680225118840517
# Cost after iteration 22563:0.26806453014189235
# Cost after iteration 22564:0.26805072896945564
# Cost after iteration 22565:0.26803230872269806
# Cost after iteration 22566:0.26800876074053875
# Cost after iteration 22567:0.26801683586334124
# Cost after iteration 22568:0.2680118686955664
# Cost after iteration 22569:0.2680228062696794
# Cost after iteration 22570:0.26803160076997307
# Cost after iteration 22571:0.2680356878618452
# Cost after iteration 22572:0.26804574384223273
# Cost after iteration 22573:0.2680330066163932
# Cost after iteration 22574:0.2679992427560414
# Cost after iteration 22575:0.26803584162634153
# Cost after iteration 22592:0.2679955206089727
# Cost after iteration 22593:0.26800160047187366
# Cost after iteration 22594:0.26793749884856605
# Cost after iteration 22595:0.26793182298538354
# Cost after iteration 22596:0.2679161823059565
# Cost after iteration 22597:0.2679386865999033
# Cost after iteration 22598:0.26787811733590816
# Cost after iteration 22599:0.2678880988080593
# Cost after iteration 22600:0.2678676271217106
# Cost after iteration 22601:0.26786833557747913
# Cost after iteration 22602:0.2678789719297313
# Cost after iteration 22603:0.26790990078670174
# Cost after iteration 22604:0.2679090563013617
# Cost after iteration 22605:0.26789367021405347
# Cost after iteration 22606:0.2678864343534715
# Cost after iteration 22607:0.267903031227285
# Cost after iteration 22624:0.2678467779393568
# Cost after iteration 22625:0.26785266210387493
# Cost after iteration 22626:0.26785520100131704
# Cost after iteration 22627:0.2678888282936987
# Cost after iteration 22628:0.26791363317768285
# Cost after iteration 22629:0.26791119300738436
# Cost after iteration 22630:0.26792182789726143
# Cost after iteration 22631:0.26795026500565383
# Cost after iteration 22632:0.26792653131620336
# Cost after iteration 22633:0.26789658620654366
# Cost after iteration 22634:0.2679227510953459
# Cost after iteration 22635:0.26797244964540096
# Cost after iteration 22636:0.2679463344490972
# Cost after iteration 22637:0.26792520933786756
# Cost after iteration 22638:0.2679353583163793
# Cost after iteration 22639:0.2679882636257458
# Cost after iteration 22656:0.26801626992165967
# Cost after iteration 22657:0.26799983261429217
# Cost after iteration 22658:0.2679986352934518
# Cost after iteration 22659:0.26803521016306436
# Cost after iteration 22660:0.26801375403241656
# Cost after iteration 22661:0.2680066699228357
# Cost after iteration 22662:0.2679971790449358
# Cost after iteration 22663:0.2680369102144115
# Cost after iteration 22664:0.2680509926797336
# Cost after iteration 22665:0.2680116093705763
# Cost after iteration 22666:0.2680228328488838
# Cost after iteration 22667:0.2680766324955436
# Cost after iteration 22668:0.26804758446900123
# Cost after iteration 22669:0.26802351452700074
# Cost after iteration 22670:0.2680416271093931
# Cost after iteration 22671:0.26809558673672207
# Cost after iteration 22688:0.26807452249602515
# Cost after iteration 22689:0.2680330219973318
# Cost after iteration 22690:0.2680183326275057
# Cost after iteration 22691:0.2680876561366562
# Cost after iteration 22692:0.26807953895268166
# Cost after iteration 22693:0.26803298759001815
# Cost after iteration 22694:0.26801009160568734
# Cost after iteration 22695:0.2680526065263509
# Cost after iteration 22696:0.2680466408803235
# Cost after iteration 22697:0.26803177687770746
# Cost after iteration 22698:0.26802235637104266
# Cost after iteration 22699:0.2680433671211251
# Cost after iteration 22700:0.2680585365993116
# Cost after iteration 22701:0.26802605866054025
# Cost after iteration 22702:0.26803173662916857
# Cost after iteration 22703:0.2680730788225034
# Cost after iteration 22720:0.2680530481128184
# Cost after iteration 22721:0.26802483787399245
# Cost after iteration 22722:0.2680158865619277
# Cost after iteration 22723:0.2680415550306004
# Cost after iteration 22724:0.2680381553088854
# Cost after iteration 22725:0.2680209661915982
# Cost after iteration 22726:0.26800099673073957
# Cost after iteration 22727:0.2680367676070202
# Cost after iteration 22728:0.26802945146475526
# Cost after iteration 22729:0.26798703983998695
# Cost after iteration 22730:0.26798533186230156
# Cost after iteration 22731:0.26802935555145085
# Cost after iteration 22732:0.26796579416101246
# Cost after iteration 22733:0.2679202454729396
# Cost after iteration 22734:0.2679073592494299
# Cost after iteration 22735:0.2679591437436147
# Cost after iteration 22752:0.26792547145123896
# Cost after iteration 22753:0.26789529830724274
# Cost after iteration 22754:0.26791755851591337
# Cost after iteration 22755:0.2679749355691162
# Cost after iteration 22756:0.2679482685710597
# Cost after iteration 22757:0.2679175722380307
# Cost after iteration 22758:0.26786261161092006
# Cost after iteration 22759:0.2678919196881543
# Cost after iteration 22760:0.2678997723574059
# Cost after iteration 22761:0.2678909126682329
# Cost after iteration 22762:0.26787859834855704
# Cost after iteration 22763:0.2679089089172997
# Cost after iteration 22764:0.26787042711649484
# Cost after iteration 22765:0.26785221936115833
# Cost after iteration 22766:0.26785336071510824
# Cost after iteration 22767:0.2679065370542064
# On the train set:
# Accuracy: 0.938388625592
# On the test set:
# Accuracy: 0.93

# %% [markdown]
# Congrats, the test set accuracy increased to 93%. You have saved the French football team!
#
# You are not overfitting the training data anymore. Let's plot the decision boundary.

# %%
plt.title("Model with L2-regularization")
axes = plt.gca()
axes.set_xlim([-0.75,0.40])
axes.set_ylim([-0.75,0.65])
plot_decision_boundary(lambda x: predict_dec(parameters, x.T), train_X, train_Y)

# %% [markdown]
# **Observations**:
# - The value of $\lambda$ is a hyperparameter that you can tune using a dev set.
# - L2 regularization makes your decision boundary smoother. If $\lambda$ is too large, it is also possible to "oversmooth", resulting in a model with high bias.
#
# **What is L2-regularization actually doing?**:
#
# L2-regularization relies on the assumption that a model with small weights is simpler than a model with large weights. Thus, by penalizing the square values of the weights in the cost function you drive all the weights to smaller values. It becomes too costly for the cost to have large weights! This leads to a smoother model in which the output changes more slowly as the input changes.
#
# <font color='blue'>
# **What you should remember** -- the implications of L2-regularization on:
# - The cost computation:
#     - A regularization term is added to the cost
# - The backpropagation function:
#     - There are extra terms in the gradients with respect to weight matrices
# - Weights end up smaller ("weight decay"):
#     - Weights are pushed to smaller values.

# %% [markdown]
# ## 3 - Dropout
#
# Finally, **dropout** is a widely used regularization technique that is specific to deep learning.
# **It randomly shuts down some neurons in each iteration.** Watch these two videos to see what this means!
#
# <!--
# To understand drop-out, consider this conversation with a friend:
# - Friend: "Why do you need all these neurons to train your network and classify images?".
# - You: "Because each neuron contains a weight and can learn specific features/details/shape of an image. The more neurons I have, the more featurse my model learns!"
# - Friend: "I see, but are you sure that your neurons are learning different features and not all the same features?"
# - You: "Good point... Neurons in the same layer actually don't talk to each other. It should be definitly possible that they learn the same image features/shapes/forms/details... which would be redundant. There should be a solution."
# !-->
#
#
# <center>
# <video width="620" height="440" src="images/dropout1_kiank.mp4" type="video/mp4" controls>
# </video>
# </center>
# <br>
# <caption><center> <u> Figure 2 </u>: Drop-out on the second hidden layer. <br> At each iteration, you shut down (= set to zero) each neuron of a layer with probability $1 - keep\_prob$ or keep it with probability $keep\_prob$ (50% here). The dropped neurons don't contribute to the training in both the forward and backward propagations of the iteration. </center></caption>
#
# <center>
# <video width="620" height="440" src="images/dropout2_kiank.mp4" type="video/mp4" controls>
# </video>
# </center>
#
# <caption><center> <u> Figure 3 </u>: Drop-out on the first and third hidden layers. <br> $1^{st}$ layer: we shut down on average 40% of the neurons.  $3^{rd}$ layer: we shut down on average 20% of the neurons. </center></caption>
#
#
# When you shut some neurons down, you actually modify your model. The idea behind drop-out is that at each iteration, you train a different model that uses only a subset of your neurons. With dropout, your neurons thus become less sensitive to the activation of one other specific neuron, because that other neuron might be shut down at any time.
#
# ### 3.1 - Forward propagation with dropout
#
# **Exercise**: Implement the forward propagation with dropout. You are using a 3 layer neural network, and will add dropout to the first and second hidden layers. We will not apply dropout to the input layer or output layer.
#
# **Instructions**:
# You would like to shut down some neurons in the first and second layers. To do that, you are going to carry out 4 Steps:
# 1. In lecture, we dicussed creating a variable $d^{[1]}$ with the same shape as $a^{[1]}$ using `np.random.rand()` to randomly get numbers between 0 and 1. Here, you will use a vectorized implementation, so create a random matrix $D^{[1]} = [d^{[1](1)} d^{[1](2)} ... d^{[1](m)}] $ of the same dimension as $A^{[1]}$.
# 2. Set each entry of $D^{[1]}$ to be 1 with probability (`keep_prob`), and 0 otherwise.
#
# **Hint:** Let's say that keep_prob = 0.8, which means that we want to keep about 80% of the neurons and drop out about 20% of them.  We want to generate a vector that has 1's and 0's, where about 80% of them are 1 and about 20% are 0.
# This python statement:
# `X = (X < keep_prob).astype(int)`
#
# is conceptually the same as this if-else statement (for the simple case of a one-dimensional array) :
#
# ```
# for i,v in enumerate(x):
#     if v < keep_prob:
#         x[i] = 1
#     else: # v >= keep_prob
#         x[i] = 0
# ```
# Note that the `X = (X < keep_prob).astype(int)` works with multi-dimensional arrays, and the resulting output preserves the dimensions of the input array.
#
# Also note that without using `.astype(int)`, the result is an array of booleans `True` and `False`, which Python automatically converts to 1 and 0 if we multiply it with numbers.  (However, it's better practice to convert data into the data type that we intend, so try using `.astype(int)`.)
#
# 3. Set $A^{[1]}$ to $A^{[1]} * D^{[1]}$. (You are shutting down some neurons). You can think of $D^{[1]}$ as a mask, so that when it is multiplied with another matrix, it shuts down some of the values.
# 4. Divide $A^{[1]}$ by `keep_prob`. By doing this you are assuring that the result of the cost will still have the same expected value as without drop-out. (This technique is also called inverted dropout.)

# %%
# GRADED FUNCTION: forward_propagation_with_dropout

def forward_propagation_with_dropout(X, parameters, keep_prob = 0.5):
    """
    Implements the forward propagation: LINEAR -> RELU + DROPOUT -> LINEAR -> RELU + DROPOUT -> LINEAR -> SIGMOID.
    
    Arguments:
    X -- input dataset, of shape (2, number of examples)
    parameters -- python dictionary containing your parameters "W1", "b1", "W2", "b2", "W3", "b3":
                    W1 -- weight matrix of shape (20, 2)
                    b1 -- bias vector of shape (20, 1)
                    W2 -- weight matrix of shape (3, 20)
                    b2 -- bias vector of shape (3, 1)
                    W3 -- weight matrix of shape (1, 3)
                    b3 -- bias vector of shape (1, 1)
    keep_prob - probability of keeping a neuron active during drop-out, scalar
    
    Returns:
    A3 -- last activation value, output of the forward propagation, of shape (1,1)
    cache -- tuple, information stored for computing the backward propagation
    """
    
    np.random.seed(1)
    
    # retrieve parameters
    W1 = parameters["W1"]
    b1 = parameters["b1"]
    W2 = parameters["W2"]
    b2 = parameters["b2"]
    W3 = parameters["W3"]
    b3 = parameters["b3"]
    
    # LINEAR -> RELU -> LINEAR -> RELU -> LINEAR -> SIGMOID
    Z1 = np.dot(W1, X) + b1
    A1 = relu(Z1)
    ### START CODE HERE ### (approx. 4 lines)         # Steps 1-4 below correspond to the Steps 1-4 described above. 
    D1 = np.random.rand(len(A1),len(A1[0]))                                         # Step 1: initialize matrix D1 = np.random.rand(..., ...)
    D1 = (D1<keep_prob).astype(int)                                         # Step 2: convert entries of D1 to 0 or 1 (using keep_prob as the threshold)
    A1 = A1*D1                                         # Step 3: shut down some neurons of A1
    A1 = A1/keep_prob                                        # Step 4: scale the value of neurons that haven't been shut down
    ### END CODE HERE ###
    Z2 = np.dot(W2, A1) + b2
    A2 = relu(Z2)
    ### START CODE HERE ### (approx. 4 lines)
    D2 = np.random.rand(len(A2),len(A2[0]))                                          # Step 1: initialize matrix D2 = np.random.rand(..., ...)
    D2 = (D2<keep_prob).astype(int)                                         # Step 2: convert entries of D2 to 0 or 1 (using keep_prob as the threshold)
    A2 = A2*D2                                         # Step 3: shut down some neurons of A2
    A2 = A2/keep_prob                                         # Step 4: scale the value of neurons that haven't been shut down
    ### END CODE HERE ###
    Z3 = np.dot(W3, A2) + b3
    A3 = sigmoid(Z3)
    
    cache = (Z1, D1, A1, W1, b1, Z2, D2, A2, W2, b2, Z3, A3, W3, b3)
    
    return A3, cache

# %%
X_assess, parameters = forward_propagation_with_dropout_test_case()

A3, cache = forward_propagation_with_dropout(X_assess, parameters, keep_prob = 0.7)
print ("A3 = " + str(A3))
# Out:
# A3 = [[ 0.36974721  0.00305176  0.04565099  0.49683389  0.36974721]]

# %% [markdown]
# **Expected Output**:
#
# <table>
#     <tr>
#     <td>
#     **A3**
#     </td>
#         <td>
#     [[ 0.36974721  0.00305176  0.04565099  0.49683389  0.36974721]]
#     </td>
#
#     </tr>
#
# </table>

# %% [markdown]
# ### 3.2 - Backward propagation with dropout
#
# **Exercise**: Implement the backward propagation with dropout. As before, you are training a 3 layer network. Add dropout to the first and second hidden layers, using the masks $D^{[1]}$ and $D^{[2]}$ stored in the cache.
#
# **Instruction**:
# Backpropagation with dropout is actually quite easy. You will have to carry out 2 Steps:
# 1. You had previously shut down some neurons during forward propagation, by applying a mask $D^{[1]}$ to `A1`. In backpropagation, you will have to shut down the same neurons, by reapplying the same mask $D^{[1]}$ to `dA1`.
# 2. During forward propagation, you had divided `A1` by `keep_prob`. In backpropagation, you'll therefore have to divide `dA1` by `keep_prob` again (the calculus interpretation is that if $A^{[1]}$ is scaled by `keep_prob`, then its derivative $dA^{[1]}$ is also scaled by the same `keep_prob`).

# %%
# GRADED FUNCTION: backward_propagation_with_dropout

def backward_propagation_with_dropout(X, Y, cache, keep_prob):
    """
    Implements the backward propagation of our baseline model to which we added dropout.
    
    Arguments:
    X -- input dataset, of shape (2, number of examples)
    Y -- "true" labels vector, of shape (output size, number of examples)
    cache -- cache output from forward_propagation_with_dropout()
    keep_prob - probability of keeping a neuron active during drop-out, scalar
    
    Returns:
    gradients -- A dictionary with the gradients with respect to each parameter, activation and pre-activation variables
    """
    
    m = X.shape[1]
    (Z1, D1, A1, W1, b1, Z2, D2, A2, W2, b2, Z3, A3, W3, b3) = cache
    
    dZ3 = A3 - Y
    dW3 = 1./m * np.dot(dZ3, A2.T)
    db3 = 1./m * np.sum(dZ3, axis=1, keepdims = True)
    dA2 = np.dot(W3.T, dZ3)
    ### START CODE HERE ### (≈ 2 lines of code)
    dA2 = dA2*D2              # Step 1: Apply mask D2 to shut down the same neurons as during the forward propagation
    dA2 = dA2/keep_prob              # Step 2: Scale the value of neurons that haven't been shut down
    ### END CODE HERE ###
    dZ2 = np.multiply(dA2, np.int64(A2 > 0))
    dW2 = 1./m * np.dot(dZ2, A1.T)
    db2 = 1./m * np.sum(dZ2, axis=1, keepdims = True)
    
    dA1 = np.dot(W2.T, dZ2)
    ### START CODE HERE ### (≈ 2 lines of code)
    dA1 = dA1*D1              # Step 1: Apply mask D1 to shut down the same neurons as during the forward propagation
    dA1 = dA1/keep_prob              # Step 2: Scale the value of neurons that haven't been shut down
    ### END CODE HERE ###
    dZ1 = np.multiply(dA1, np.int64(A1 > 0))
    dW1 = 1./m * np.dot(dZ1, X.T)
    db1 = 1./m * np.sum(dZ1, axis=1, keepdims = True)
    
    gradients = {"dZ3": dZ3, "dW3": dW3, "db3": db3,"dA2": dA2,
                 "dZ2": dZ2, "dW2": dW2, "db2": db2, "dA1": dA1, 
                 "dZ1": dZ1, "dW1": dW1, "db1": db1}
    
    return gradients

# %%
X_assess, Y_assess, cache = backward_propagation_with_dropout_test_case()

gradients = backward_propagation_with_dropout(X_assess, Y_assess, cache, keep_prob = 0.8)

print ("dA1 = \n" + str(gradients["dA1"]))
print ("dA2 = \n" + str(gradients["dA2"]))
# Out:
# dA1 =
# [[ 0.36544439  0.         -0.00188233  0.         -0.17408748]
#  [ 0.65515713  0.         -0.00337459  0.         -0.        ]]
# dA2 =
# [[ 0.58180856  0.         -0.00299679  0.         -0.27715731]
#  [ 0.          0.53159854 -0.          0.53159854 -0.34089673]
#  [ 0.          0.         -0.00292733  0.         -0.        ]]

# %% [markdown]
# **Expected Output**:
#
# ```
# dA1 =
# [[ 0.36544439  0.         -0.00188233  0.         -0.17408748]
#  [ 0.65515713  0.         -0.00337459  0.         -0.        ]]
# dA2 =
# [[ 0.58180856  0.         -0.00299679  0.         -0.27715731]
#  [ 0.          0.53159854 -0.          0.53159854 -0.34089673]
#  [ 0.          0.         -0.00292733  0.         -0.        ]]
# ```

# %% [markdown]
# Let's now run the model with dropout (`keep_prob = 0.86`). It means at every iteration you shut down each neurons of layer 1 and 2 with 14% probability. The function `model()` will now call:
# - `forward_propagation_with_dropout` instead of `forward_propagation`.
# - `backward_propagation_with_dropout` instead of `backward_propagation`.

# %%
parameters = model(train_X, train_Y, keep_prob = 0.86, learning_rate = 0.3)

print ("On the train set:")
predictions_train = predict(train_X, train_Y, parameters)
print ("On the test set:")
predictions_test = predict(test_X, test_Y, parameters)
# Out:
# Cost after iteration 0:0.6543912405149825
# Cost after iteration 1:0.6471562109769352
# Cost after iteration 2:0.6398799179895095
# Cost after iteration 3:0.6323736960579537
# Cost after iteration 4:0.6244747408518447
# Cost after iteration 5:0.6164689331956767
# Cost after iteration 6:0.6083513014265239
# Cost after iteration 7:0.6000083482639228
# Cost after iteration 8:0.5915925633982113
# Cost after iteration 9:0.5833290774657024
# Cost after iteration 10:0.575330608126489
# Cost after iteration 11:0.567391150167655
# Cost after iteration 12:0.5595184262990154
# Cost after iteration 13:0.5515713125992567
# Cost after iteration 14:0.5436979697857552
# Cost after iteration 15:0.5357637419350949
# Cost after iteration 32:0.4284687845344425
# Cost after iteration 33:0.42385031601671525
# Cost after iteration 34:0.4194319850982625
# Cost after iteration 35:0.4152167208179389
# Cost after iteration 36:0.41124418560067033
# Cost after iteration 37:0.40746112837862625
# Cost after iteration 38:0.40387270998728764
# Cost after iteration 39:0.4004762375845301
# Cost after iteration 40:0.3972394583542195
# Cost after iteration 41:0.3941944438233354
# Cost after iteration 42:0.3912885268775636
# Cost after iteration 43:0.38852394115528605
# Cost after iteration 44:0.3859052620860497
# Cost after iteration 45:0.383404635721516
# Cost after iteration 46:0.38101492570246875
# Cost after iteration 47:0.37873043329937073
# Cost after iteration 64:0.34462901666338913
# Cost after iteration 65:0.3431909349000149
# Cost after iteration 66:0.34181101778439343
# Cost after iteration 67:0.3404896864841717
# Cost after iteration 68:0.3392106511393923
# Cost after iteration 69:0.3379727607768761
# Cost after iteration 70:0.3367686691952477
# Cost after iteration 71:0.3356129772101647
# Cost after iteration 72:0.3344962355874037
# Cost after iteration 73:0.33341182271912406
# Cost after iteration 74:0.3323544744126611
# Cost after iteration 75:0.3313229094100304
# Cost after iteration 76:0.3303156787084146
# Cost after iteration 77:0.32936554971347204
# Cost after iteration 78:0.3284477656074402
# Cost after iteration 79:0.3275553760409973
# Cost after iteration 96:0.3159905658782468
# Cost after iteration 97:0.3154470932596046
# Cost after iteration 98:0.31491609331804366
# Cost after iteration 99:0.31439936939888485
# Cost after iteration 100:0.3138985629756521
# Cost after iteration 101:0.31341567714230995
# Cost after iteration 102:0.3129434620899739
# Cost after iteration 103:0.3124798362891172
# Cost after iteration 104:0.31202311753144407
# Cost after iteration 105:0.31157855044714244
# Cost after iteration 106:0.31119448614756257
# Cost after iteration 107:0.3108008005127923
# Cost after iteration 108:0.3104959535123809
# Cost after iteration 109:0.3100254154294832
# Cost after iteration 110:0.3096806580884221
# Cost after iteration 111:0.3092923349118215
# Cost after iteration 128:0.3041585237574173
# Cost after iteration 129:0.3038784587027505
# Cost after iteration 130:0.30361877228871853
# Cost after iteration 131:0.3033624084079753
# Cost after iteration 132:0.3031123436884966
# Cost after iteration 133:0.3028866045320111
# Cost after iteration 134:0.30262169836884695
# Cost after iteration 135:0.3023781150516869
# Cost after iteration 136:0.30213682982392254
# Cost after iteration 137:0.30189469320113893
# Cost after iteration 138:0.3016567758393378
# Cost after iteration 139:0.3014210210219581
# Cost after iteration 140:0.3011881555411474
# Cost after iteration 141:0.30095720065531145
# Cost after iteration 142:0.30072913568813786
# Cost after iteration 143:0.30050288436188405
# Cost after iteration 160:0.2961778975443397
# Cost after iteration 161:0.2958823708472795
# Cost after iteration 162:0.2955942192076007
# Cost after iteration 163:0.2953141967828129
# Cost after iteration 164:0.29508130500527563
# Cost after iteration 165:0.29481255402508416
# Cost after iteration 166:0.29453646764020003
# Cost after iteration 167:0.2943015757147249
# Cost after iteration 168:0.29406285984606767
# Cost after iteration 169:0.29383197245560366
# Cost after iteration 170:0.2935832764127109
# Cost after iteration 171:0.29334868168428696
# Cost after iteration 172:0.29314473558975107
# Cost after iteration 173:0.2929153969031793
# Cost after iteration 174:0.29270988447359686
# Cost after iteration 175:0.2924792760003037
# Cost after iteration 192:0.2886440043639325
# Cost after iteration 193:0.2884093480137053
# Cost after iteration 194:0.2881841140556974
# Cost after iteration 195:0.28796064851507436
# Cost after iteration 196:0.2877385271955334
# Cost after iteration 197:0.28754196696973283
# Cost after iteration 198:0.28732825458711814
# Cost after iteration 199:0.28710556407449306
# Cost after iteration 200:0.28688959700015537
# Cost after iteration 201:0.2866785100970721
# Cost after iteration 202:0.286451155583068
# Cost after iteration 203:0.28627415760657854
# Cost after iteration 204:0.28603231704475696
# Cost after iteration 205:0.285808522653729
# Cost after iteration 206:0.28560074012791564
# Cost after iteration 207:0.2853967720518063
# Cost after iteration 224:0.28227296451314415
# Cost after iteration 225:0.28204196926975156
# Cost after iteration 226:0.28185495494476526
# Cost after iteration 227:0.2817264575746129
# Cost after iteration 228:0.2814850427830081
# Cost after iteration 229:0.28131320941787413
# Cost after iteration 230:0.28116895994474617
# Cost after iteration 231:0.28092965671309716
# Cost after iteration 232:0.2807545007712803
# Cost after iteration 233:0.2806096254080214
# Cost after iteration 234:0.2803690474984911
# Cost after iteration 235:0.28019555434460003
# Cost after iteration 236:0.2800498462219919
# Cost after iteration 237:0.27980630525399364
# Cost after iteration 238:0.27962577459597815
# Cost after iteration 239:0.27944079993583365
# Cost after iteration 2048:0.10140571398765931
# Cost after iteration 2049:0.10094146656443581
# Cost after iteration 2050:0.10107852873351016
# Cost after iteration 2051:0.1014237242914259
# Cost after iteration 2052:0.10111045761101871
# Cost after iteration 2053:0.1011592582711419
# Cost after iteration 2054:0.10070140562201875
# Cost after iteration 2055:0.10050574532980436
# Cost after iteration 2056:0.10084066566446515
# Cost after iteration 2057:0.10144431046748914
# Cost after iteration 2058:0.10309019861362459
# Cost after iteration 2059:0.10224479664909648
# Cost after iteration 2060:0.10379851878146883
# Cost after iteration 2061:0.1044201558397788
# Cost after iteration 2062:0.10552554645081123
# Cost after iteration 2063:0.10379375260857436
# Cost after iteration 2080:0.09998348937794199
# Cost after iteration 2219:0.09398046690879804
# Cost after iteration 2220:0.09485365375478075
# Cost after iteration 2221:0.09493094015605226
# Cost after iteration 2222:0.09762196760363581
# Cost after iteration 2223:0.09670137543941318
# Cost after iteration 2240:0.09425234523142989
# Cost after iteration 2241:0.09394520176301192
# Cost after iteration 2242:0.096058992080997
# Cost after iteration 2243:0.09554187222479155
# Cost after iteration 2244:0.09480621092129624
# Cost after iteration 2245:0.09393807999790083
# Cost after iteration 2246:0.09590668789373932
# Cost after iteration 2247:0.09529045887613265
# Cost after iteration 2248:0.09466750649336565
# Cost after iteration 2249:0.0938995464799975
# Cost after iteration 2250:0.09585206212748687
# Cost after iteration 2251:0.09414080392963181
# Cost after iteration 2252:0.09444082795174959
# Cost after iteration 2253:0.0942814330445078
# Cost after iteration 2254:0.09512294573570605
# Cost after iteration 2255:0.09359554315265933
# Cost after iteration 2272:0.09407986782800025
# Cost after iteration 2273:0.0928337374186228
# Cost after iteration 2274:0.09493802708488537
# Cost after iteration 2275:0.09318985866033541
# Cost after iteration 2276:0.0933135737533123
# Cost after iteration 2277:0.09315713816413143
# Cost after iteration 2278:0.09397783777512225
# Cost after iteration 2279:0.09253920129027995
# Cost after iteration 2280:0.09273903260720877
# Cost after iteration 2281:0.09264627971818042
# Cost after iteration 2282:0.09387492588252
# Cost after iteration 2283:0.09331786138395685
# Cost after iteration 2284:0.09314534152347502
# Cost after iteration 2285:0.09229031873262769
# Cost after iteration 2286:0.09329053591903413
# Cost after iteration 2287:0.09237705554577755
# /home/jovyan/work/week5/Regularization/reg_utils.py:236: RuntimeWarning: divide by zero encountered in log
#   logprobs = np.multiply(-np.log(a3),Y) + np.multiply(-np.log(1 - a3), 1 - Y)
# /home/jovyan/work/week5/Regularization/reg_utils.py:236: RuntimeWarning: invalid value encountered in multiply
#   logprobs = np.multiply(-np.log(a3),Y) + np.multiply(-np.log(1 - a3), 1 - Y)
# Cost after iteration 4096:0.06660323681799811
# Cost after iteration 4097:0.06671725934373426
# Cost after iteration 4098:0.06883641689498848
# Cost after iteration 4099:0.06714461789676733
# Cost after iteration 4100:0.06676925590936975
# Cost after iteration 4101:0.06663633983436895
# Cost after iteration 4102:0.06680345801018979
# Cost after iteration 4103:0.06706626699452778
# Cost after iteration 4104:0.06675526624752307
# Cost after iteration 4105:0.06671951900859817
# Cost after iteration 4106:0.06708684550638781
# Cost after iteration 4107:0.06660162983753959
# Cost after iteration 4108:0.06655566852919254
# Cost after iteration 4109:0.06672261980639109
# Cost after iteration 4110:0.06659710075324196
# Cost after iteration 4111:0.06662529030298082
# Cost after iteration 4128:0.06663536392279211
# Cost after iteration 4129:0.06851745858227622
# Cost after iteration 4130:0.06689382833357647
# Cost after iteration 4131:0.06658709294090137
# Cost after iteration 4132:0.06651022926676436
# Cost after iteration 4133:0.066639647868554
# Cost after iteration 4134:0.06688395880388684
# Cost after iteration 4135:0.06657818972211646
# Cost after iteration 4136:0.06659959252031036
# Cost after iteration 4137:0.06764969683955134
# Cost after iteration 18439:0.06057610756347815
# Cost after iteration 18440:0.060572197162898724
# Cost after iteration 18441:0.06056924839708187
# Cost after iteration 18442:0.060666323786876794
# Cost after iteration 18443:0.06065777389413783
# Cost after iteration 18444:0.060649854100753124
# Cost after iteration 18445:0.06065301765124607
# Cost after iteration 18446:0.060656454817546474
# Cost after iteration 18447:0.06064875151387227
# Cost after iteration 18464:0.06059843023838561
# Cost after iteration 18465:0.06059349311549804
# Cost after iteration 18466:0.06058889937078112
# Cost after iteration 18467:0.060584619013631075
# Cost after iteration 18468:0.06058059293543833
# Cost after iteration 18469:0.06057682831809433
# Cost after iteration 18470:0.06058485774526404
# Cost after iteration 18471:0.0606017709671753
# Cost after iteration 18472:0.060594707406677044
# Cost after iteration 18473:0.060588514660549785
# Cost after iteration 18474:0.060605685223288075
# Cost after iteration 18475:0.0606382457470375
# Cost after iteration 18476:0.060631969900860234
# Cost after iteration 18477:0.060641137497689464
# Cost after iteration 18478:0.0606463116479113
# Cost after iteration 18479:0.06063815360667627
# Cost after iteration 18496:0.06074212219436519
# Cost after iteration 18497:0.06070398741503277
# Cost after iteration 18498:0.060678558940980204
# Cost after iteration 18499:0.060659744271772384
# Cost after iteration 18500:0.06064491991714426
# Cost after iteration 18501:0.06063279861049957
# Cost after iteration 18502:0.06062264168129965
# Cost after iteration 18503:0.060613961940112177
# Cost after iteration 18504:0.06060642398937256
# Cost after iteration 18505:0.060599788458501704
# Cost after iteration 18506:0.06059432610097814
# Cost after iteration 18507:0.06061764282995351
# Cost after iteration 18508:0.06060946342362869
# Cost after iteration 18509:0.0606022756568736
# Cost after iteration 18510:0.060595922960857425
# Cost after iteration 18511:0.0605902825429389
# Cost after iteration 18528:0.06060591585128162
# Cost after iteration 18529:0.06060165373517054
# Cost after iteration 18530:0.060602486513586344
# Cost after iteration 18531:0.06061004702044293
# Cost after iteration 18532:0.06060517382470048
# Cost after iteration 18533:0.06060059354298383
# Cost after iteration 18534:0.06059629495773417
# Cost after iteration 18535:0.06059244347641291
# Cost after iteration 18536:0.0605991293104407
# Cost after iteration 18537:0.06061034344147354
# Cost after iteration 18538:0.060604802170396085
# Cost after iteration 18539:0.06059954321441209
# Cost after iteration 18540:0.06059468200815011
# Cost after iteration 18541:0.06059016390227295
# Cost after iteration 18542:0.0605861875961544
# Cost after iteration 18543:0.060582444727899025
# Cost after iteration 18560:0.060606761170557216
# Cost after iteration 18561:0.06060193852082782
# Cost after iteration 18562:0.06059721636632941
# Cost after iteration 18563:0.06059273838011949
# Cost after iteration 18564:0.06058871422762029
# Cost after iteration 18565:0.060584982753505386
# Cost after iteration 18566:0.06058148064387005
# Cost after iteration 18567:0.060578336333742815
# Cost after iteration 18568:0.06057542032941605
# Cost after iteration 18569:0.060572830977297036
# Cost after iteration 18570:0.06059408360911683
# Cost after iteration 18571:0.060589601200659385
# Cost after iteration 18572:0.060585355505227895
# Cost after iteration 18573:0.06060526937035613
# Cost after iteration 18574:0.06069608663471639
# Cost after iteration 18575:0.060680500264407106
# Cost after iteration 18592:0.06060302397341042
# Cost after iteration 18593:0.060598661239735035
# Cost after iteration 18594:0.06059456776847619
# Cost after iteration 18595:0.060590684713699466
# Cost after iteration 18596:0.060587003438653586
# Cost after iteration 18597:0.060583672372731184
# Cost after iteration 18598:0.06058029416965973
# Cost after iteration 18599:0.06057708295175632
# Cost after iteration 18600:0.0605917101089023
# Cost after iteration 18601:0.060744025310144445
# Cost after iteration 18602:0.06070284926746606
# Cost after iteration 18603:0.060675123585323176
# Cost after iteration 18604:0.06065493693408287
# Cost after iteration 18605:0.06063924479594424
# Cost after iteration 18606:0.060626534258565
# Cost after iteration 18607:0.06061595886692273
# Cost after iteration 18624:0.06066353643732944
# Cost after iteration 18625:0.0606554620158606
# Cost after iteration 18626:0.06064792104342004
# Cost after iteration 18627:0.060640860078933836
# Cost after iteration 18628:0.06063423537807723
# Cost after iteration 18629:0.06062800859428598
# Cost after iteration 18630:0.060622139518539175
# Cost after iteration 18631:0.060616603249166075
# Cost after iteration 18632:0.060611398364256754
# Cost after iteration 18633:0.06060663390860462
# Cost after iteration 18634:0.060602100850896776
# Cost after iteration 18635:0.06059778229538413
# Cost after iteration 18636:0.060608536487527745
# Cost after iteration 18637:0.06061335844732894
# Cost after iteration 18638:0.060607888550819354
# Cost after iteration 18639:0.06060281725835307
# Cost after iteration 18656:0.060573478085725226
# Cost after iteration 18657:0.060570001516466215
# Cost after iteration 18658:0.06056673876983458
# Cost after iteration 18659:0.060563817958689516
# Cost after iteration 18660:0.06056348563610965
# Cost after iteration 18661:0.06058329308026488
# Cost after iteration 18662:0.06057855179531127
# Cost after iteration 18663:0.0605742888187391
# Cost after iteration 18664:0.06061231830557845
# Cost after iteration 18665:0.06066401146001543
# Cost after iteration 18666:0.060655688956617056
# Cost after iteration 18667:0.06064795449243568
# Cost after iteration 18668:0.06064073516423379
# Cost after iteration 18669:0.0606339817470436
# Cost after iteration 18670:0.06062764496792886
# Cost after iteration 18671:0.06062176515038219
# Cost after iteration 20480:0.060539889057816355
# Cost after iteration 20481:0.06055867263459298
# Cost after iteration 20482:0.06055487609534055
# Cost after iteration 20483:0.06055132482241116
# Cost after iteration 20484:0.06054809549873498
# Cost after iteration 20485:0.06054498243891932
# Cost after iteration 20486:0.06054203590908746
# Cost after iteration 20487:0.06053929362380023
# Cost after iteration 20488:0.060580293166482856
# Cost after iteration 20489:0.06064357477821683
# Cost after iteration 20490:0.06063617027453577
# Cost after iteration 20491:0.06062922754090233
# Cost after iteration 20492:0.06062270722837552
# Cost after iteration 20493:0.06061656620237901
# Cost after iteration 20494:0.060610778364899476
# Cost after iteration 20495:0.06060530458592889
# Cost after iteration 20512:0.06055366982819698
# Cost after iteration 20513:0.060557561792135166
# Cost after iteration 20514:0.06060935354467412
# Cost after iteration 20515:0.060599564267155966
# Cost after iteration 20516:0.060591265726455394
# Cost after iteration 20517:0.060583791197033623
# Cost after iteration 20518:0.06057706200714056
# Cost after iteration 20519:0.060570964877075716
# Cost after iteration 20520:0.06056595233612957
# Cost after iteration 20521:0.060561763846011696
# Cost after iteration 20522:0.06055787727808069
# Cost after iteration 20523:0.060554274745323475
# Cost after iteration 20524:0.060550951865272505
# Cost after iteration 20525:0.060547736041619504
# Cost after iteration 20526:0.06054480681526098
# Cost after iteration 20527:0.06058389754632239
# Cost after iteration 20544:0.060604779013750304
# Cost after iteration 20545:0.06059919823698315
# Cost after iteration 20546:0.06059393564125131
# Cost after iteration 20547:0.060588959248621045
# Cost after iteration 20548:0.06058423963693017
# Cost after iteration 20549:0.06057975796106321
# Cost after iteration 20550:0.06057553210381114
# Cost after iteration 20551:0.06057164657228515
# Cost after iteration 20552:0.06057172974814548
# Cost after iteration 20553:0.06058555718682018
# Cost after iteration 20554:0.060580668316331666
# Cost after iteration 20555:0.06057608017495438
# Cost after iteration 20556:0.06057175364615879
# Cost after iteration 20557:0.06056768812713525
# Cost after iteration 20558:0.06056388183172421
# Cost after iteration 20559:0.06056027489329812
# Cost after iteration 20576:0.060547576355824584
# Cost after iteration 20577:0.060544101177919675
# Cost after iteration 20578:0.06057142154162545
# Cost after iteration 20579:0.06068589093696809
# Cost after iteration 20580:0.06065451804392741
# Cost after iteration 20581:0.06063222761201473
# Cost after iteration 20582:0.060615146126133515
# Cost after iteration 20583:0.06060153966696177
# Cost after iteration 20584:0.06059038282981983
# Cost after iteration 20585:0.06058102989816677
# Cost after iteration 20586:0.06057306216722456
# Cost after iteration 20587:0.06056615339328216
# Cost after iteration 20588:0.06056008670105992
# Cost after iteration 20589:0.060573560025087896
# Cost after iteration 20590:0.06058271651880198
# Cost after iteration 20591:0.0605732997278687
# Cost after iteration 20608:0.060563179329465956
# Cost after iteration 20609:0.060560034042789194
# Cost after iteration 20610:0.06055689747963976
# Cost after iteration 20611:0.06055394584340804
# Cost after iteration 20612:0.06055120141967511
# Cost after iteration 20613:0.06054952796022118
# Cost after iteration 20614:0.060571340056521435
# Cost after iteration 20615:0.06056633287325402
# Cost after iteration 20616:0.06056169906536726
# Cost after iteration 20617:0.06055742957595387
# Cost after iteration 20618:0.060553475921322895
# Cost after iteration 20619:0.060549925093285606
# Cost after iteration 20620:0.06054650559778895
# Cost after iteration 20621:0.06054328542733418
# Cost after iteration 20622:0.060540255517997785
# Cost after iteration 20623:0.06053752271623636
# Cost after iteration 20640:0.060572284657051
# Cost after iteration 20641:0.06056852548027352
# Cost after iteration 20642:0.06056493529712744
# Cost after iteration 20643:0.06056151835403225
# Cost after iteration 20644:0.06055834006797132
# Cost after iteration 20645:0.06055529127240481
# Cost after iteration 20646:0.06055249539017223
# Cost after iteration 20647:0.060555490852051946
# Cost after iteration 20648:0.06056840815351957
# Cost after iteration 20649:0.06056962579405533
# Cost after iteration 20650:0.06058373599968094
# Cost after iteration 20651:0.06057782458257177
# Cost after iteration 20652:0.060572488891664285
# Cost after iteration 20653:0.06056762679105797
# Cost after iteration 20654:0.06056315962757882
# Cost after iteration 20655:0.060559013946030964
# Cost after iteration 20672:0.060573604299224024
# Cost after iteration 20673:0.060569753790931505
# Cost after iteration 20674:0.06056606313619307
# Cost after iteration 20675:0.06056246852095438
# Cost after iteration 20676:0.06055919244167262
# Cost after iteration 20677:0.06055592516364319
# Cost after iteration 20678:0.06055282584706165
# Cost after iteration 20679:0.060561362303954154
# Cost after iteration 20680:0.06056571684361306
# Cost after iteration 20681:0.060561574523880446
# Cost after iteration 20682:0.060557644043635804
# Cost after iteration 20683:0.06055430267062426
# Cost after iteration 20684:0.060551143125668734
# Cost after iteration 20685:0.06054824948037124
# Cost after iteration 20686:0.06054555618863463
# Cost after iteration 20687:0.060542924297014016
# Cost after iteration 20704:0.06058236844931616
# Cost after iteration 20705:0.06057808355403213
# Cost after iteration 20706:0.060574011883389005
# Cost after iteration 20707:0.060570141065878755
# Cost after iteration 20708:0.060566487492362264
# Cost after iteration 20709:0.06056306366723702
# Cost after iteration 20710:0.060559679179236894
# Cost after iteration 20711:0.060556511153012346
# Cost after iteration 20712:0.060553507966801264
# Cost after iteration 20713:0.060550541567206906
# Cost after iteration 20714:0.06054784897379703
# Cost after iteration 20715:0.06054525079073053
# Cost after iteration 20716:0.06055115890721609
# Cost after iteration 20717:0.06059793478268478
# Cost after iteration 20718:0.060589065532094456
# Cost after iteration 20719:0.060581448575986005
# Cost after iteration 22528:0.06054698269432609
# Cost after iteration 22529:0.06054376599626479
# Cost after iteration 22530:0.06054068005155389
# Cost after iteration 22531:0.060537861425899814
# Cost after iteration 22532:0.060535032733092985
# Cost after iteration 22533:0.060532452061670475
# Cost after iteration 22534:0.06053003460945136
# Cost after iteration 22535:0.06052760526830964
# Cost after iteration 22536:0.06052534772222353
# Cost after iteration 22537:0.060523129635562146
# Cost after iteration 22538:0.060520962280691544
# Cost after iteration 22539:0.06053965107433725
# Cost after iteration 22540:0.06057548045364794
# Cost after iteration 22541:0.06056714623303958
# Cost after iteration 22542:0.06055996269090036
# Cost after iteration 22543:0.06055362413318779
# Cost after iteration 22560:0.060510359635684415
# Cost after iteration 22561:0.060526651887272014
# Cost after iteration 22562:0.060622912844286385
# Cost after iteration 22563:0.060591723908438394
# Cost after iteration 22564:0.06058613785141847
# Cost after iteration 22565:0.06058086928429498
# Cost after iteration 22566:0.060575888075713145
# Cost after iteration 22567:0.06057117678218731
# Cost after iteration 22568:0.060566709450271566
# Cost after iteration 22569:0.06056246975852308
# Cost after iteration 22570:0.060558467826736156
# Cost after iteration 22571:0.060554661556072184
# Cost after iteration 22572:0.06055103103455297
# Cost after iteration 22573:0.0605475696755798
# Cost after iteration 22574:0.06055138468571292
# Cost after iteration 22575:0.060563438933145364
# Cost after iteration 22592:0.06052919291534803
# Cost after iteration 22593:0.06052627589785581
# Cost after iteration 22594:0.06052345150116414
# Cost after iteration 22595:0.06052077475284469
# Cost after iteration 22596:0.06051825740571746
# Cost after iteration 22597:0.060515964890119546
# Cost after iteration 22598:0.0605223841323154
# Cost after iteration 22599:0.060549142605249136
# Cost after iteration 22600:0.060542649966904644
# Cost after iteration 22601:0.060536918870663675
# Cost after iteration 22602:0.06053182250428592
# Cost after iteration 22603:0.06052723359310818
# Cost after iteration 22604:0.06052308755228023
# Cost after iteration 22605:0.060519296735702596
# Cost after iteration 22606:0.06051582697272716
# Cost after iteration 22607:0.06052199361265937
# Cost after iteration 22624:0.060637103761464126
# Cost after iteration 22625:0.06062780644528414
# Cost after iteration 22626:0.06061925797934547
# Cost after iteration 22627:0.06061138410194604
# Cost after iteration 22628:0.06061951578378508
# Cost after iteration 22629:0.06061186786758857
# Cost after iteration 22630:0.06060472373444918
# Cost after iteration 22631:0.060598034553784146
# Cost after iteration 22632:0.060591758621127166
# Cost after iteration 22633:0.06058587188968124
# Cost after iteration 22634:0.06058035155379668
# Cost after iteration 22635:0.06057522307374795
# Cost after iteration 22636:0.06057045603984255
# Cost after iteration 22637:0.060566050946486434
# Cost after iteration 22638:0.0605620204160549
# Cost after iteration 22639:0.06055805322319551
# Cost after iteration 22656:0.06052411928421924
# Cost after iteration 22657:0.06052141334288878
# Cost after iteration 22658:0.0605188822556849
# Cost after iteration 22659:0.060516559864888866
# Cost after iteration 22660:0.060514429830377116
# Cost after iteration 22661:0.060524437046401515
# Cost after iteration 22662:0.060549198525706484
# Cost after iteration 22663:0.06054429331197231
# Cost after iteration 22664:0.06053995131089699
# Cost after iteration 22665:0.06053605821375038
# Cost after iteration 22666:0.06053246411880714
# Cost after iteration 22667:0.060529115835429345
# Cost after iteration 22668:0.060526010509067626
# Cost after iteration 22669:0.06052311377741342
# Cost after iteration 22670:0.060520380087247416
# Cost after iteration 22671:0.060517801062235886
# Cost after iteration 22688:0.06056302233599868
# Cost after iteration 22689:0.060558905211002254
# Cost after iteration 22690:0.0605549898947948
# Cost after iteration 22691:0.06055126343936709
# Cost after iteration 22692:0.06054771426656791
# Cost after iteration 22693:0.060544325027358764
# Cost after iteration 22694:0.060541085988539
# Cost after iteration 22695:0.06053803982379021
# Cost after iteration 22696:0.06053516862824621
# Cost after iteration 22697:0.06053697746798843
# Cost after iteration 22698:0.06054731353657491
# Cost after iteration 22699:0.060543799036782045
# Cost after iteration 22700:0.06054046217176382
# Cost after iteration 22701:0.06053728215005891
# Cost after iteration 22702:0.06053424715960725
# Cost after iteration 22703:0.060531364980640316
# Cost after iteration 22720:0.06052012055895557
# Cost after iteration 22721:0.06051734525933714
# Cost after iteration 22722:0.06051485597796481
# Cost after iteration 22723:0.060512502659536366
# Cost after iteration 22724:0.06051023463155622
# Cost after iteration 22725:0.06050809534903259
# Cost after iteration 22726:0.06050611751160462
# Cost after iteration 22727:0.06051544318448846
# Cost after iteration 22728:0.060701433956330784
# Cost after iteration 22729:0.06060386186316219
# Cost after iteration 22730:0.060594921722165324
# Cost after iteration 22731:0.06058691409347237
# Cost after iteration 22732:0.06057967655591819
# Cost after iteration 22733:0.06057314794810405
# Cost after iteration 22734:0.06056720321349992
# Cost after iteration 22735:0.06056177773224376
# Cost after iteration 22752:0.06051394599980237
# Cost after iteration 22753:0.06051960835238947
# Cost after iteration 22754:0.0605173888744624
# Cost after iteration 22755:0.06051518892827155
# Cost after iteration 22756:0.060513107257388905
# Cost after iteration 22757:0.060511236615740614
# Cost after iteration 22758:0.060509344948974225
# Cost after iteration 22759:0.06051832251300507
# Cost after iteration 22760:0.06056306224603352
# Cost after iteration 22761:0.06055466240103515
# Cost after iteration 22762:0.06054734488787641
# Cost after iteration 22763:0.06054099028750482
# Cost after iteration 22764:0.060535389611292297
# Cost after iteration 22765:0.060530456649920905
# Cost after iteration 22766:0.06053577394309027
# Cost after iteration 22767:0.060607589592651286
# On the train set:
# Accuracy: 0.928909952607
# On the test set:
# Accuracy: 0.95

# %% [markdown]
# Dropout works great! The test accuracy has increased again (to 95%)! Your model is not overfitting the training set and does a great job on the test set. The French football team will be forever grateful to you!
#
# Run the code below to plot the decision boundary.

# %%
plt.title("Model with dropout")
axes = plt.gca()
axes.set_xlim([-0.75,0.40])
axes.set_ylim([-0.75,0.65])
plot_decision_boundary(lambda x: predict_dec(parameters, x.T), train_X, train_Y)

# %% [markdown]
# **Note**:
# - A **common mistake** when using dropout is to use it both in training and testing. You should use dropout (randomly eliminate nodes) only in training.
# - Deep learning frameworks like [tensorflow](https://www.tensorflow.org/api_docs/python/tf/nn/dropout), [PaddlePaddle](http://doc.paddlepaddle.org/release_doc/0.9.0/doc/ui/api/trainer_config_helpers/attrs.html), [keras](https://keras.io/layers/core/#dropout) or [caffe](http://caffe.berkeleyvision.org/tutorial/layers/dropout.html) come with a dropout layer implementation. Don't stress - you will soon learn some of these frameworks.
#
# <font color='blue'>
# **What you should remember about dropout:**
# - Dropout is a regularization technique.
# - You only use dropout during training. Don't use dropout (randomly eliminate nodes) during test time.
# - Apply dropout both during forward and backward propagation.
# - During training time, divide each dropout layer by keep_prob to keep the same expected value for the activations. For example, if keep_prob is 0.5, then we will on average shut down half the nodes, so the output will be scaled by 0.5 since only the remaining half are contributing to the solution. Dividing by 0.5 is equivalent to multiplying by 2. Hence, the output now has the same expected value. You can check that this works even when keep_prob is other values than 0.5.

# %% [markdown]
# ## 4 - Conclusions

# %% [markdown]
# **Here are the results of our three models**:
#
# <table>
#     <tr>
#         <td>
#         **model**
#         </td>
#         <td>
#         **train accuracy**
#         </td>
#         <td>
#         **test accuracy**
#         </td>
#
#     </tr>
#         <td>
#         3-layer NN without regularization
#         </td>
#         <td>
#         95%
#         </td>
#         <td>
#         91.5%
#         </td>
#     <tr>
#         <td>
#         3-layer NN with L2-regularization
#         </td>
#         <td>
#         94%
#         </td>
#         <td>
#         93%
#         </td>
#     </tr>
#     <tr>
#         <td>
#         3-layer NN with dropout
#         </td>
#         <td>
#         93%
#         </td>
#         <td>
#         95%
#         </td>
#     </tr>
# </table>

# %% [markdown]
# Note that regularization hurts training set performance! This is because it limits the ability of the network to overfit to the training set. But since it ultimately gives better test accuracy, it is helping your system.

# %% [markdown]
# Congratulations for finishing this assignment! And also for revolutionizing French football. :-)

# %% [markdown]
# <font color='blue'>
# **What we want you to remember from this notebook**:
# - Regularization will help you reduce overfitting.
# - Regularization will drive your weights to lower values.
# - L2 regularization and Dropout are two very effective regularization techniques.
